# %%
# importing the now modularized machine learning process for integration
from absenteeism_module import *

# using model on a fresh, unseen data data set
# instantiating model class
model = absenteeism_model('model', 'scaler')

# cleaning new data using custom method
model.load_and_clean_data('Absenteeism_new_data.csv')

# displaying predictions. The prediction feature is the final conclusion. 
# If below 50% probability, the result is zero
# Above 50% probability is 1
model.predicted_outputs()
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
# importing pymysql to integrate python and sql
import pymysql

# %%
conn = pymysql.connect(database='predicted_outputs', user='root', password='NEWPASSWORD')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     570                                 (self.host, self.port), self.connect_timeout,
# --> 571                                 **kwargs)
#     572                             break
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
